# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline

# %%
data = pd.read_csv('FBI Crime Data 2013.csv')
data.head()
# Out:
#                        City  Population  Violent\rcrime  \
# 0             Adams Village        1861               0
# 1  Addison Town and Village        2577               3
# 2             Akron Village        2846               3
# 3                    Albany       97956             791
# 4            Albion Village        6388              23
#
#    Murder and\rnonnegligent\rmanslaughter  Rape\r(revised\rdefinition)1  \
# 0                                       0                           NaN
# 1                                       0                           NaN
# 2                                       0                           NaN
# 3                                       8                           NaN
# 4                                       0                           NaN
#
#    Rape\r(legacy\rdefinition)2  Robbery  Aggravated\rassault  Property\rcrime  \
# 0                            0        0                    0               12
# 1                            0        0                    3               24
# 2                            0        0                    3               16
# 3                           30      227                  526             4090
# 4                            3        4                   16              223
#
#    Burglary  Larceny-\rtheft  Motor\rvehicle\rtheft  Arson3
# 0         2               10                      0     0.0
# 1         3               20                      1     0.0
# 2         1               15                      0     0.0
# 3       705             3243                    142     NaN
# 4        53              165                      5     NaN

# %%
# Data cleaning

# Rename columns
data.columns = [['City', 'Population', 'Violent Crime', 'Murder', 'Rape1', 'Rape2', 'Robbery', 'Agg Assault', 'Property Crime',
                'Burglary', 'Larceny', 'Vehicle Theft', 'Arson']]

cols = ['Population', 'Violent Crime', 'Murder', 'Rape1', 'Rape2', 'Robbery', 'Agg Assault', 'Property Crime',
        'Burglary', 'Larceny', 'Vehicle Theft', 'Arson']

# Replace all NaN with 0
data[cols] = data[cols].replace(np.nan, 0)

# %%
# Add New Boolean columns for Murder and Robbery
data['PopSq'] = data['Population'] ** 2
data['MurderBool'] = np.where((data['Murder'] >= 1), 1, 0)
data['RobberyBool'] = np.where((data['Robbery'] >= 1), 1, 0)

# %%
data.head()
# Out:
#                        City Population Violent Crime Murder Rape1 Rape2  \
# 0             Adams Village       1861             0      0   0.0     0
# 1  Addison Town and Village       2577             3      0   0.0     0
# 2             Akron Village       2846             3      0   0.0     0
# 3                    Albany      97956           791      8   0.0    30
# 4            Albion Village       6388            23      0   0.0     3
#
#   Robbery Agg Assault Property Crime Burglary Larceny Vehicle Theft Arson  \
# 0       0           0             12        2      10             0   0.0
# 1       0           3             24        3      20             1   0.0
# 2       0           3             16        1      15             0   0.0
# 3     227         526           4090      705    3243           142   0.0
# 4       4          16            223       53     165             5   0.0
#
#         PopSq MurderBool RobberyBool
# 0     3463321          0           0
# 1     6640929          0           0
# 2     8099716          0           0
# 3  9595377936          1           1
# 4    40806544          0           1
